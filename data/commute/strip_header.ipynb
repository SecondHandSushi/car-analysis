# %%
import os
import pandas as pd

# Use the current directory
directory = '.'  

# Iterate over all files in the directory
for filename in os.listdir(directory):
    # Check if the file is a CSV
    if filename.endswith('.csv'):
        file_path = os.path.join(directory, filename)
        
        try:
            # Read the CSV file, skip the first row
            df = pd.read_csv(file_path, header=None, skiprows=1)
            
            # Save the modified DataFrame back to the same file
            df.to_csv(file_path, index=False, header=False)
            print(f"Processed: {filename}")
        
        except Exception as e:
            print(f"Error processing {filename}: {e}")

print("All files processed.")
# Out:
# Processed: CSVLog_20240802_062846.csv
# Processed: CSVLog_20240802_141351.csv
# Processed: CSVLog_20240805_060612.csv
# Processed: CSVLog_20240805_144518.csv
# Processed: CSVLog_20240806_062605.csv
# Processed: CSVLog_20240806_150356.csv
# Processed: CSVLog_20240807_061944.csv
# Processed: CSVLog_20240807_151137.csv
# Processed: CSVLog_20240808_061137.csv
# Processed: CSVLog_20240808_145841.csv
# Processed: CSVLog_20240809_144036.csv
# Processed: CSVLog_20240812_061559.csv
# Processed: CSVLog_20240812_150145.csv
# Processed: CSVLog_20240813_061624.csv
# Processed: CSVLog_20240813_150034.csv
# Processed: CSVLog_20240814_061431.csv
# Processed: CSVLog_20240816_055756.csv
# Processed: CSVLog_20240817_123639.csv
# Processed: CSVLog_20240817_172803.csv
# Processed: CSVLog_20240819_061427.csv
# Processed: CSVLog_20240820_062018.csv
# Processed: CSVLog_20240820_150118.csv
# Processed: CSVLog_20240821_061438.csv
# Processed: CSVLog_20240822_061503.csv
# Processed: CSVLog_20240822_144757.csv
# Processed: CSVLog_20240823_060546.csv
# Processed: CSVLog_20240826_062554.csv
# Processed: CSVLog_20240826_145715.csv
# Processed: CSVLog_20240827_150004.csv
# Processed: CSVLog_20240828_061457.csv
# Processed: CSVLog_20240903_052232.csv
# Processed: CSVLog_20240903_141714.csv
# Processed: CSVLog_20240904_061338.csv
# Processed: CSVLog_20240904_152502.csv
# Processed: CSVLog_20240905_062432.csv
# Processed: CSVLog_20240905_143329.csv
# Processed: CSVLog_20240906_060602.csv
# Processed: CSVLog_20240909_055540.csv
# Processed: CSVLog_20240909_143203.csv
# Processed: CSVLog_20240910_055308.csv
# Processed: CSVLog_20240910_143624.csv
# Processed: CSVLog_20240911_060016.csv
# Processed: CSVLog_20240911_143509.csv
# Processed: CSVLog_20240912_055918.csv
# Processed: CSVLog_20240912_143341.csv
# Processed: CSVLog_20240913_054404.csv
# Processed: CSVLog_20240913_134933.csv
# Processed: CSVLog_20240916_054505.csv
# Processed: CSVLog_20240916_143547.csv
# Processed: CSVLog_20240917_060547.csv
# Processed: CSVLog_20240917_143208.csv
# Processed: CSVLog_20240918_055220.csv
# Processed: CSVLog_20240918_141705.csv
# Processed: CSVLog_20240919_060219.csv
# Processed: CSVLog_20240919_143451.csv
# Processed: CSVLog_20240920_055547.csv
# Processed: CSVLog_20240920_142241.csv
# Processed: CSVLog_20240921_183122.csv
# Processed: CSVLog_20240923_060438.csv
# Processed: CSVLog_20240923_144010.csv
# Processed: CSVLog_20240924_055653.csv
# Processed: CSVLog_20240924_143403.csv
# Processed: CSVLog_20240924_162344.csv
# Processed: CSVLog_20240924_173203.csv
# Processed: CSVLog_20240925_055028.csv
# All files processed.
